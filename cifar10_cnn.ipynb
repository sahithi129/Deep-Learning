# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import numpy
numpy.__path__
# Out:
# ['C:\\Users\\sahit\\Anaconda3\\lib\\site-packages\\numpy']

# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(10,10))
for i in range(12):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
#     ax.imshow(np.squeeze(x_train[i]))
    ax.imshow(x_train[i])

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 41s - loss: 1.5772 - acc: 0.4290 - val_loss: 1.3677 - val_acc: 0.4958
#
# Epoch 00001: val_loss improved from inf to 1.36768, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 43s - loss: 1.2591 - acc: 0.5512 - val_loss: 1.1032 - val_acc: 0.6052
#
# Epoch 00002: val_loss improved from 1.36768 to 1.10317, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 47s - loss: 1.1385 - acc: 0.6002 - val_loss: 1.0877 - val_acc: 0.6132
#
# Epoch 00003: val_loss improved from 1.10317 to 1.08772, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 42s - loss: 1.0716 - acc: 0.6271 - val_loss: 0.9861 - val_acc: 0.6568
#
# Epoch 00004: val_loss improved from 1.08772 to 0.98610, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 41s - loss: 1.0353 - acc: 0.6380 - val_loss: 0.9817 - val_acc: 0.6536
#
# Epoch 00005: val_loss improved from 0.98610 to 0.98165, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 40s - loss: 1.0131 - acc: 0.6506 - val_loss: 1.0491 - val_acc: 0.6448
#
# Epoch 00006: val_loss did not improve from 0.98165
# Epoch 7/50
#  - 39s - loss: 1.0008 - acc: 0.6568 - val_loss: 1.0088 - val_acc: 0.6602
#
# Epoch 00007: val_loss did not improve from 0.98165
# Epoch 8/50
#  - 39s - loss: 1.0040 - acc: 0.6592 - val_loss: 0.9675 - val_acc: 0.6662
#
# Epoch 00008: val_loss improved from 0.98165 to 0.96749, saving model to model.weights.best.hdf5
# Epoch 9/50
#  - 39s - loss: 1.0064 - acc: 0.6598 - val_loss: 1.0030 - val_acc: 0.6520
#
# Epoch 00009: val_loss did not improve from 0.96749
# Epoch 10/50
#  - 39s - loss: 1.0108 - acc: 0.6592 - val_loss: 0.9413 - val_acc: 0.6836
#
# Epoch 00010: val_loss improved from 0.96749 to 0.94129, saving model to model.weights.best.hdf5
# Epoch 11/50
#  - 39s - loss: 1.0178 - acc: 0.6585 - val_loss: 1.0415 - val_acc: 0.6554
#
# Epoch 00011: val_loss did not improve from 0.94129
# Epoch 12/50
#  - 45s - loss: 1.0273 - acc: 0.6566 - val_loss: 1.0511 - val_acc: 0.6534
#
# Epoch 00012: val_loss did not improve from 0.94129
# Epoch 13/50
#  - 46s - loss: 1.0414 - acc: 0.6503 - val_loss: 1.0706 - val_acc: 0.6612
#
# Epoch 00013: val_loss did not improve from 0.94129
# Epoch 14/50
#  - 47s - loss: 1.0609 - acc: 0.6473 - val_loss: 1.0772 - val_acc: 0.6658
#
# Epoch 00014: val_loss did not improve from 0.94129
# Epoch 15/50
#  - 41s - loss: 1.0735 - acc: 0.6447 - val_loss: 1.1548 - val_acc: 0.6092
#
# Epoch 00015: val_loss did not improve from 0.94129
# Epoch 16/50
#  - 41s - loss: 1.0880 - acc: 0.6377 - val_loss: 1.1835 - val_acc: 0.6270
#
# Epoch 00016: val_loss did not improve from 0.94129
# Epoch 17/50
#  - 41s - loss: 1.1016 - acc: 0.6337 - val_loss: 0.9732 - val_acc: 0.6666
#
# Epoch 00017: val_loss did not improve from 0.94129
# Epoch 18/50
#  - 44s - loss: 1.1213 - acc: 0.6290 - val_loss: 1.0945 - val_acc: 0.6248
#
# Epoch 00018: val_loss did not improve from 0.94129
# Epoch 19/50
#  - 44s - loss: 1.1462 - acc: 0.6230 - val_loss: 0.9949 - val_acc: 0.6748
#
# Epoch 00019: val_loss did not improve from 0.94129
# Epoch 20/50
#  - 40s - loss: 1.1489 - acc: 0.6216 - val_loss: 1.2075 - val_acc: 0.6480
#
# Epoch 00020: val_loss did not improve from 0.94129
# Epoch 21/50
#  - 46s - loss: 1.1709 - acc: 0.6137 - val_loss: 1.4512 - val_acc: 0.5996
#
# Epoch 00021: val_loss did not improve from 0.94129
# Epoch 22/50
#  - 45s - loss: 1.1932 - acc: 0.6062 - val_loss: 1.1606 - val_acc: 0.6152
#
# Epoch 00022: val_loss did not improve from 0.94129
# Epoch 23/50
#  - 42s - loss: 1.2240 - acc: 0.6010 - val_loss: 1.3442 - val_acc: 0.5686
#
# Epoch 00023: val_loss did not improve from 0.94129
# Epoch 24/50
#  - 41s - loss: 1.2356 - acc: 0.5934 - val_loss: 1.1403 - val_acc: 0.6196
#
# Epoch 00024: val_loss did not improve from 0.94129
# Epoch 25/50
#  - 49s - loss: 1.2591 - acc: 0.5866 - val_loss: 1.2690 - val_acc: 0.6278
#
# Epoch 00025: val_loss did not improve from 0.94129
# Epoch 26/50
#  - 81s - loss: 1.2776 - acc: 0.5783 - val_loss: 1.1617 - val_acc: 0.6234
#
# Epoch 00026: val_loss did not improve from 0.94129
# Epoch 27/50
#  - 80s - loss: 1.3077 - acc: 0.5757 - val_loss: 1.6108 - val_acc: 0.5426
#
# Epoch 00027: val_loss did not improve from 0.94129
# Epoch 28/50
#  - 80s - loss: 1.3381 - acc: 0.5625 - val_loss: 2.4633 - val_acc: 0.4698
#
# Epoch 00028: val_loss did not improve from 0.94129
# Epoch 29/50
#  - 86s - loss: 1.3414 - acc: 0.5578 - val_loss: 1.4264 - val_acc: 0.4824
#
# Epoch 00029: val_loss did not improve from 0.94129
# Epoch 30/50
#  - 89s - loss: 1.3634 - acc: 0.5523 - val_loss: 1.2236 - val_acc: 0.6098
#
# Epoch 00030: val_loss did not improve from 0.94129
# Epoch 31/50
#  - 80s - loss: 1.3653 - acc: 0.5514 - val_loss: 2.3782 - val_acc: 0.4858
#
# Epoch 00031: val_loss did not improve from 0.94129
# Epoch 32/50
#  - 78s - loss: 1.3965 - acc: 0.5377 - val_loss: 1.3365 - val_acc: 0.6068
#
# Epoch 00032: val_loss did not improve from 0.94129
# Epoch 33/50
#  - 76s - loss: 1.3875 - acc: 0.5442 - val_loss: 1.4391 - val_acc: 0.5242
#
# Epoch 00033: val_loss did not improve from 0.94129
# Epoch 34/50
#  - 77s - loss: 1.4280 - acc: 0.5314 - val_loss: 1.4139 - val_acc: 0.5598
#
# Epoch 00034: val_loss did not improve from 0.94129
# Epoch 35/50
#  - 80s - loss: 1.4358 - acc: 0.5249 - val_loss: 1.2002 - val_acc: 0.5932
#
# Epoch 00035: val_loss did not improve from 0.94129
# Epoch 36/50
#  - 83s - loss: 1.4541 - acc: 0.5189 - val_loss: 1.3093 - val_acc: 0.5418
#
# Epoch 00036: val_loss did not improve from 0.94129
# Epoch 37/50
#  - 86s - loss: 1.4634 - acc: 0.5177 - val_loss: 1.4831 - val_acc: 0.5356
#
# Epoch 00037: val_loss did not improve from 0.94129
# Epoch 38/50
#  - 76s - loss: 1.4866 - acc: 0.5114 - val_loss: 1.4402 - val_acc: 0.5400
#
# Epoch 00038: val_loss did not improve from 0.94129
# Epoch 39/50
#  - 75s - loss: 1.4863 - acc: 0.5063 - val_loss: 1.5118 - val_acc: 0.5036
#
# Epoch 00039: val_loss did not improve from 0.94129
# Epoch 40/50
#  - 77s - loss: 1.5004 - acc: 0.4989 - val_loss: 1.7213 - val_acc: 0.3872
#
# Epoch 00040: val_loss did not improve from 0.94129
# Epoch 41/50
#  - 91s - loss: 1.5048 - acc: 0.5000 - val_loss: 1.3457 - val_acc: 0.5184
#
# Epoch 00041: val_loss did not improve from 0.94129
# Epoch 42/50
#  - 91s - loss: 1.5109 - acc: 0.4975 - val_loss: 1.6460 - val_acc: 0.4600
#
# Epoch 00042: val_loss did not improve from 0.94129
# Epoch 43/50
#  - 91s - loss: 1.5314 - acc: 0.4914 - val_loss: 2.3944 - val_acc: 0.4472
#
# Epoch 00043: val_loss did not improve from 0.94129
# Epoch 44/50
#  - 80s - loss: 1.5657 - acc: 0.4790 - val_loss: 1.4751 - val_acc: 0.5222
#
# Epoch 00044: val_loss did not improve from 0.94129
# Epoch 45/50
#  - 76s - loss: 1.5768 - acc: 0.4751 - val_loss: 1.5511 - val_acc: 0.4660
#
# Epoch 00045: val_loss did not improve from 0.94129
# Epoch 46/50
#  - 77s - loss: 1.5903 - acc: 0.4688 - val_loss: 1.6575 - val_acc: 0.4648
#
# Epoch 00046: val_loss did not improve from 0.94129
# Epoch 47/50
#  - 75s - loss: 1.5842 - acc: 0.4693 - val_loss: 1.8207 - val_acc: 0.4312
#
# Epoch 00047: val_loss did not improve from 0.94129
# Epoch 48/50
#  - 76s - loss: 1.5875 - acc: 0.4659 - val_loss: 1.3017 - val_acc: 0.5562
#
# Epoch 00048: val_loss did not improve from 0.94129
# Epoch 49/50
#  - 77s - loss: 1.6057 - acc: 0.4576 - val_loss: 1.3929 - val_acc: 0.5098
#
# Epoch 00049: val_loss did not improve from 0.94129
# Epoch 50/50
#  - 77s - loss: 1.6080 - acc: 0.4547 - val_loss: 4.0562 - val_acc: 0.3548
#
# Epoch 00050: val_loss did not improve from 0.94129

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6684

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
